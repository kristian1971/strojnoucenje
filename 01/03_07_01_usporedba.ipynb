# %%
from sklearn import (datasets, metrics,
    model_selection as skms,
    naive_bayes, neighbors)

iris = datasets.load_iris()
(iris_train_ftrs, iris_test_ftrs,
    iris_train_tgt, iris_test_tgt) = skms.train_test_split(iris.data,
    iris.target,
    test_size=.90,
    random_state=42)
models = {'kNN': neighbors.KNeighborsClassifier(n_neighbors=3),
          'NB' : naive_bayes.GaussianNB()}
for name, model in models.items():
    fit = model.fit(iris_train_ftrs, iris_train_tgt)
    predictions = fit.predict(iris_test_ftrs)
    score = metrics.accuracy_score(iris_test_tgt, predictions)
    print("{:>3s}: {:0.2f}".format(name,score))
# Out:
# kNN: 0.96
#  NB: 0.81

# %%
# %timeit -r1 datasets.load_iris()
# Out:
# 660 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1000 loops each)

# %%
# %%timeit -r1 -n1
(iris_train_ftrs, iris_test_ftrs,
iris_train_tgt, iris_test_tgt) = skms.train_test_split(iris.data,
iris.target,
test_size=.25)
# Out:
# 598 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
# %%timeit -r1
nb = naive_bayes.GaussianNB()
fit = nb.fit(iris_train_ftrs, iris_train_tgt)
preds = fit.predict(iris_test_ftrs)
metrics.accuracy_score(iris_test_tgt, preds)
# Out:
# 2.01 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1000 loops each)

# %%
# %%timeit -r1
knn = neighbors.KNeighborsClassifier(n_neighbors=3)
fit = knn.fit(iris_train_ftrs, iris_train_tgt)
preds = fit.predict(iris_test_ftrs)
metrics.accuracy_score(iris_test_tgt, preds)
# Out:
# 2.44 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 100 loops each)

# %%
# fitting
nb = naive_bayes.GaussianNB()
# %timeit -r1 fit = nb.fit(iris_train_ftrs, iris_train_tgt)
knn = neighbors.KNeighborsClassifier(n_neighbors=3)
# %timeit -r1 fit = knn.fit(iris_train_ftrs, iris_train_tgt)
# Out:
# 891 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1000 loops each)
# 690 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1000 loops each)

# %%
# predicting
nb = naive_bayes.GaussianNB()
fit = nb.fit(iris_train_ftrs, iris_train_tgt)
# %timeit -r1 preds = fit.predict(iris_test_ftrs)
knn = neighbors.KNeighborsClassifier(n_neighbors=3)
fit = knn.fit(iris_train_ftrs, iris_train_tgt)
# %timeit -r1 preds = fit.predict(iris_test_ftrs)
# Out:
# 328 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1000 loops each)
# 1.43 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1000 loops each)

# %%
# !pip install memory_profiler
# %load_ext memory_profiler
# Out:
# Collecting memory_profiler
#   Downloading memory_profiler-0.61.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from memory_profiler) (5.9.5)
# Downloading memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# Installing collected packages: memory_profiler
# Successfully installed memory_profiler-0.61.0

# %%
# %%memit
# nb = naive_bayes.GaussianNB()
# fit = nb.fit(iris_train_ftrs, iris_train_tgt)
# preds = fit.predict(iris_test_ftrs)
# Out:
# peak memory: 258.81 MiB, increment: 0.07 MiB

# %%
# %%memit
# knn = neighbors.KNeighborsClassifier(n_neighbors=3)
# fit = knn.fit(iris_train_ftrs, iris_train_tgt)
# preds = fit.predict(iris_test_ftrs)
# Out:
# peak memory: 259.11 MiB, increment: 0.00 MiB
